# %% [markdown]
# # Imports

# %%
from IPython.core.display import display
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.pipeline import Pipeline, make_pipeline
from riski_ml import PandasFeatureUnion, PandasOneHotEncoder,EstimatorSelectionHelper
from riski_ml.transformers.dataframe_transformers import *
from show_and_tell.utils import get_data
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Config

# %%
DATA_FOLDER_PATH = Path("test_data")
TRAIN_PATH = DATA_FOLDER_PATH/"house_prices_regression.csv"
LABEL_COL_NAME = 'SalePrice'
TEST_PROPORTION_SIZE = 0.1
RANDOM_STATE = 42
FINAL_MODEL_PATH = 'show_and_tell/finalized_model.sav'
NAN_PROPORTION_TO_REMOVE = 0.5

# %% [markdown]
# # Data Import

# %%
from sklearn.model_selection import train_test_split
X,y = get_data(TRAIN_PATH, LABEL_COL_NAME)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_PROPORTION_SIZE, random_state=RANDOM_STATE)

# %% [markdown]
# # Quick data exploration

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    html_str = ''
    for df in args:
        html_str += df.to_html()
    display_html(html_str.replace('table', 'table style="display:inline"'), raw=True)

def object_columns_unique_and_missing_values(df):
    cols = ['column', 'type', '#_unique', '% missing_values']
    cols_metadata = [[col, df[col].dtype, len(df[col].value_counts()), df[col].isna().sum()/df.shape[0]] for col in df.columns]
    return pd.DataFrame(cols_metadata, columns = cols).sort_values('% missing_values')

display_side_by_side(*[object_columns_unique_and_missing_values(X_train.select_dtypes(dtype)) for dtype in ['O','int64', 'float64']])
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column</th>
#       <th>type</th>
#       <th>#_unique</th>
#       <th>% missing_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>MSZoning</td>
#       <td>object</td>
#       <td>5</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Street</td>
#       <td>object</td>
#       <td>2</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>LotShape</td>
#       <td>object</td>
#       <td>4</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>LandContour</td>
#       <td>object</td>
#       <td>4</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Utilities</td>
#       <td>object</td>
#       <td>2</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>LotConfig</td>
#       <td>object</td>
#       <td>5</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>LandSlope</td>
#       <td>object</td>
#       <td>3</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Neighborhood</td>
#       <td>object</td>
#       <td>25</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Condition1</td>
#       <td>object</td>
#       <td>9</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Alley</td>
#       <td>object</td>
#       <td>2</td>
#       <td>0.934551</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column</th>
#       <th>type</th>
#       <th>#_unique</th>
#       <th>% missing_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Id</td>
#       <td>int64</td>
#       <td>1314</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>MiscVal</td>
#       <td>int64</td>
#       <td>20</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>PoolArea</td>
#       <td>int64</td>
#       <td>8</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>ScreenPorch</td>
#       <td>int64</td>
#       <td>74</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>3SsnPorch</td>
#       <td>int64</td>
#       <td>19</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>EnclosedPorch</td>
#       <td>int64</td>
#       <td>112</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>OpenPorchSF</td>
#       <td>int64</td>
#       <td>195</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>WoodDeckSF</td>
#       <td>int64</td>
#       <td>260</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>GarageArea</td>
#       <td>int64</td>
#       <td>416</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>GarageCars</td>
#       <td>int64</td>
#       <td>5</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Fireplaces</td>
#       <td>int64</td>
#       <td>4</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>TotRmsAbvGrd</td>
#       <td>int64</td>
#       <td>12</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>KitchenAbvGr</td>
#       <td>int64</td>
#       <td>4</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>BedroomAbvGr</td>
#       <td>int64</td>
#       <td>8</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>HalfBath</td>
#       <td>int64</td>
#       <td>3</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>FullBath</td>
#       <td>int64</td>
#       <td>4</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>BsmtHalfBath</td>
#       <td>int64</td>
#       <td>3</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>BsmtFullBath</td>
#       <td>int64</td>
#       <td>4</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MSSubClass</td>
#       <td>int64</td>
#       <td>15</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>LotArea</td>
#       <td>int64</td>
#       <td>978</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OverallQual</td>
#       <td>int64</td>
#       <td>10</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>OverallCond</td>
#       <td>int64</td>
#       <td>9</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>YearBuilt</td>
#       <td>int64</td>
#       <td>112</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>YearRemodAdd</td>
#       <td>int64</td>
#       <td>61</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>MoSold</td>
#       <td>int64</td>
#       <td>12</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BsmtFinSF1</td>
#       <td>int64</td>
#       <td>592</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BsmtUnfSF</td>
#       <td>int64</td>
#       <td>732</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>TotalBsmtSF</td>
#       <td>int64</td>
#       <td>679</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1stFlrSF</td>
#       <td>int64</td>
#       <td>708</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2ndFlrSF</td>
#       <td>int64</td>
#       <td>394</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>LowQualFinSF</td>
#       <td>int64</td>
#       <td>21</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>GrLivArea</td>
#       <td>int64</td>
#       <td>793</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>BsmtFinSF2</td>
#       <td>int64</td>
#       <td>126</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>YrSold</td>
#       <td>int64</td>
#       <td>5</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column</th>
#       <th>type</th>
#       <th>#_unique</th>
#       <th>% missing_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>MasVnrArea</td>
#       <td>float64</td>
#       <td>306</td>
#       <td>0.006088</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>GarageYrBlt</td>
#       <td>float64</td>
#       <td>95</td>
#       <td>0.055556</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>LotFrontage</td>
#       <td>float64</td>
#       <td>108</td>
#       <td>0.180365</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# # 1. Basic Usage

# %%
from sklearn.linear_model import LinearRegression
preprocess = Pipeline([('select_columns', ColumnRemover(['Id'])),
                       ('object_to_cat_or_num', ObjectsColumnaAsType()),
                       ('remove_nan_columns', NanColumnsRemover()),
                       ('feature_union', PandasFeatureUnion(transformer_list=[
                           ("numeric_features", make_pipeline(
                               TypeSelector(np.number),
                               PandasImputer(strategy="mean"),
                               PandasStandardScaler()
                           )),
                           ("categorical_features", make_pipeline(
                               TypeSelector("category"),
                               CatToInt(),
                               PandasImputer(strategy="most_frequent"),
                               PandasOneHotEncoder()
                           )),
                           ("boolean_features", make_pipeline(
                               TypeSelector(bool),
                               PandasImputer(strategy="most_frequent"),
                               BoolToInt(),
                           )),
                           
                       ])),
                       ])

preprocess.fit(X_train)
preprocess.transform(X_train).head(2)
# Out:
#      MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 907   -0.174883     0.733776  0.084557     0.650071     1.282993  -1.149679
# 782   -0.880863    -0.126500  0.543774     0.650071    -0.520058   0.984929
#
#      YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Condition1_0  \
# 907      0.105391   -0.588127   -0.489611   -0.279269  ...             1
# 782      0.830435   -0.588127   -0.979513   -0.279269  ...             1
#
#      Condition1_6  Condition1_1  Condition1_7  Condition1_4  Condition1_5  \
# 907             0             0             0             0             0
# 782             0             0             0             0             0
#
#      Condition1_8  Street  Alley  Utilities
# 907             0       1      1          1
# 782             0       1      1          1
#
# [2 rows x 94 columns]

# %%
preprocess.transform(X_test).head(2)
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 892    -0.880863     0.009333 -0.211606    -0.078142     2.184519  -0.262996
# 1105    0.060443     1.277108  0.157111     1.378284    -0.520058   0.755048
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Condition1_2  \
# 892       0.878772   -0.588127    0.477012   -0.279269  ...             0
# 1105      0.492081    1.462934    1.287656   -0.279269  ...             0
#
#       Condition1_3  Condition1_4  Condition1_5  Condition1_6  Condition1_7  \
# 892              0             0             0             0             0
# 1105             0             0             0             0             0
#
#       Condition1_8  Street  Alley  Utilities
# 892              0       1      1          1
# 1105             0       1      1          1
#
# [2 rows x 94 columns]

# %%
preprocess.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'select_columns', 'object_to_cat_or_num', 'remove_nan_columns', 'feature_union', 'select_columns__cols', 'remove_nan_columns__p', 'feature_union__n_jobs', 'feature_union__transformer_list', 'feature_union__transformer_weights', 'feature_union__verbose', 'feature_union__numeric_features', 'feature_union__categorical_features', 'feature_union__boolean_features', 'feature_union__numeric_features__memory', 'feature_union__numeric_features__steps', 'feature_union__numeric_features__verbose', 'feature_union__numeric_features__typeselector', 'feature_union__numeric_features__pandasimputer', 'feature_union__numeric_features__pandasstandardscaler', 'feature_union__numeric_features__typeselector__dtype', 'feature_union__numeric_features__pandasimputer__strategy', 'feature_union__categorical_features__memory', 'feature_union__categorical_features__steps', 'feature_union__categorical_features__verbose', 'feature_union__categorical_features__typeselector', 'feature_union__categorical_features__cattoint', 'feature_union__categorical_features__pandasimputer', 'feature_union__categorical_features__pandasonehotencoder', 'feature_union__categorical_features__typeselector__dtype', 'feature_union__categorical_features__pandasimputer__strategy', 'feature_union__boolean_features__memory', 'feature_union__boolean_features__steps', 'feature_union__boolean_features__verbose', 'feature_union__boolean_features__typeselector', 'feature_union__boolean_features__pandasimputer', 'feature_union__boolean_features__booltoint', 'feature_union__boolean_features__typeselector__dtype', 'feature_union__boolean_features__pandasimputer__strategy'])

# %% [markdown]
# ## Accesssing objects is easy
# Also named_steps in the pipeline allows autocomple

# %%
print(preprocess.named_steps.remove_nan_columns.columns_to_remove)
preprocess.named_steps.feature_union.transformer_list[0][1][-1].transformer.mean_
# Out:
# []
# array([5.74315068e+01, 6.97938719e+01, 1.06189201e+04, 6.10730594e+00,
#        5.57686454e+00, 1.97100837e+03, 1.98481963e+03, 1.03800919e+02,
#        4.45867580e+02, 4.33515982e+01, 5.67424658e+02, 1.05664384e+03,
#        1.16369787e+03, 3.50787671e+02, 5.45433790e+00, 1.51993988e+03,
#        4.24657534e-01, 5.78386606e-02, 1.57153729e+00, 3.83561644e-01,
#        2.87747336e+00, 1.04870624e+00, 6.54261796e+00, 6.16438356e-01,
#        1.97857293e+03, 1.76940639e+00, 4.72396499e+02, 9.48759513e+01,
#        4.78850837e+01, 2.21324201e+01, 3.77092846e+00, 1.52587519e+01,
#        3.06544901e+00, 4.66773212e+01, 6.34474886e+00, 2.00781963e+03])

# %%
# Show autocomplete
# preprocess.named_steps

# %% [markdown]
# ## Piping a classifer

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,LinearRegression

clf_pipeline = Pipeline([
    ('preprocess', preprocess),
    ('clf', Lasso())
])
params = {'preprocess__remove_nan_columns__p':[0.2],
          'clf__alpha': [1,2]} 
clf = GridSearchCV(clf_pipeline, params)
clf.fit(X_train, y_train)
pd.DataFrame(clf.cv_results_)
# Out:
# /Users/afek.adler/opt/anaconda3/envs/riski_ml/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6554578497.128418, tolerance: 647410209.5552388
#   model = cd_fast.enet_coordinate_descent(
# /Users/afek.adler/opt/anaconda3/envs/riski_ml/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9835369150.90332, tolerance: 649740038.5132324
#   model = cd_fast.enet_coordinate_descent(
# /Users/afek.adler/opt/anaconda3/envs/riski_ml/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6663977026.296875, tolerance: 647410209.5552388
#   model = cd_fast.enet_coordinate_descent(
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.107805      0.006443         0.047608        0.000744
# 1       0.091855      0.011874         0.046934        0.001380
#
#   param_clf__alpha param_preprocess__remove_nan_columns__p  \
# 0                1                                     0.2
# 1                2                                     0.2
#
#                                               params  split0_test_score  \
# 0  {'clf__alpha': 1, 'preprocess__remove_nan_colu...           0.843353
# 1  {'clf__alpha': 2, 'preprocess__remove_nan_colu...           0.843644
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0            0.66133           0.529361           0.831640           0.587038
# 1            0.66199           0.529841           0.832344           0.590720
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.690544        0.127126                2
# 1         0.691708        0.126606                1

# %%
clf.predict(X_test)
# Out:
# array([155150.6991462 , 265590.56276628, 123561.91399295, 233344.42131596,
#        264867.70606823,  41011.05903581, 219735.20500982, 139529.34760413,
#         39129.46852104, 151365.24660418, 145754.93064197, 157387.34755024,
#         61287.31851214, 184102.50114609, 179793.78286339, 149492.70772431,
#        194429.01191481, 146023.16723807, 104158.53463624, 213060.17827771,
#        178966.00721306, 179560.78838086, 174702.68259917, 138063.08313353,
#        192707.85279361, 135790.95773261, 181566.81296771,  85801.36418166,
#        171126.29277503, 153964.50886944, 169686.6152043 , 237857.0105874 ,
#        225512.51389609, 104435.46800127, 234818.68464954, 166381.33019247,
#        157228.50641755, 205051.97754253, 272472.54704247,  99485.57351663,
#        184828.69337654, 230420.9356078 , 116803.15487145, 242418.51551271,
#        125078.94576989, 143387.61070646, 112504.68078661, 134035.30263316,
#        310842.56620586, 147891.43049783, 126181.20443822, 254252.38557954,
#         84248.32153935, 294730.79229866, 133710.49288489, 230884.46386324,
#        211828.08147756, 172416.72119947, 142559.05499874, 118368.13300962,
#        114962.77764432, 155442.67876315, 250346.5402443 , 220766.34452915,
#        250714.15824341, 210740.09683362, 113674.14706735, 272483.1792518 ,
#        146780.81075869, 140118.24987167, 106127.92774986, 124958.90111215,
#         97699.58331117,  73677.01383585, 332269.35647101, 188642.57806481,
#        253976.63397552, 256860.94859416, 139160.25160131,  95722.05358947,
#        113133.97036426,  74638.2459764 , 177823.69067107, 111034.29135131,
#        162850.64524749, 168587.64465645, 223129.22092246, 213048.41821142,
#        130846.63986826, 187718.52446544, 164670.98886025, 167173.10131117,
#        165174.57672332, 241289.64745012, 113324.89903416, 170155.6166036 ,
#        227930.30851315, 120232.37239883, 192399.52939729, 275786.8680395 ,
#        164821.34048684, 212751.77585019, 285997.36875617, 194167.09240319,
#        193418.45793347, 183766.64528406, 172503.04991255, 239531.62994303,
#        137619.23655609, 205134.87564389,  83832.86835011, 136647.50821554,
#        142700.37373609, 181104.06391236, 199738.83630658, 131364.84161961,
#        103152.83281947, 128508.78262136, 138176.90568916, 242562.85067402,
#        143689.36925024, 129985.52573972, 187225.86099261, 219733.15590728,
#        177130.79741583, 134326.45788162, 217592.83491591, 138465.25576013,
#        137650.5415149 , 220397.82645348, 182181.42154346, 277989.59769876,
#        186767.10711584, 149308.5117527 ,   8047.36149769, 268059.61362137,
#        257882.85123738, 130884.25940582, 225269.56802015, 398436.94834654,
#        271344.50960425, 131198.03851599, 176545.01584266, 133184.10114125,
#         89782.55119857, 125479.94729298])

# %%
print(np.mean(np.sqrt(np.square(clf.predict(X_test) - y_test))))
np.mean(np.sqrt(np.square(clf.predict(X_train) - y_train)))
# Out:
# 30985.145126827112
# 18403.789139702094

# %% [markdown]
# # Testing multiple algorithms is easy
#
# Multiprocessing

# %%
clf_pipeline = Pipeline([
    ('preprocess', preprocess),
    ('clf', 'passthrough')
])

param_grid = [
    {'clf': [Lasso()],
     'clf__alpha': [1,2,3]
    },
    {'clf': [LinearRegression()],
    },
]

clf = GridSearchCV(clf_pipeline, n_jobs=8, param_grid=param_grid, scoring = 'neg_mean_absolute_error')
clf.fit(X, y)
pd.DataFrame(clf.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.175849      0.013394         0.068545        0.005419
# 1       0.159272      0.018241         0.069203        0.006779
# 2       0.156011      0.028570         0.066403        0.004594
# 3       0.093988      0.012056         0.056562        0.007746
#
#             param_clf param_clf__alpha  \
# 0      Lasso(alpha=3)                1
# 1      Lasso(alpha=3)                2
# 2      Lasso(alpha=3)                3
# 3  LinearRegression()              NaN
#
#                                      params  split0_test_score  \
# 0  {'clf': Lasso(alpha=3), 'clf__alpha': 1}      -31112.697687
# 1  {'clf': Lasso(alpha=3), 'clf__alpha': 2}      -30881.836475
# 2  {'clf': Lasso(alpha=3), 'clf__alpha': 3}      -30651.332291
# 3               {'clf': LinearRegression()}      -31261.113014
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0      -28152.472921      -23181.246812      -20186.061809      -27257.005904
# 1      -28108.096254      -23153.395457      -20162.898088      -27230.077166
# 2      -28062.499100      -23124.496245      -20141.061052      -27201.883984
# 3      -28359.986301      -38257.739726      -23552.761986      -27426.047945
#
#    mean_test_score  std_test_score  rank_test_score
# 0    -25977.897027     3849.615183                3
# 1    -25907.260688     3792.661342                2
# 2    -25836.254534     3736.173023                1
# 3    -29771.529795     4907.166807                4

# %% [markdown]
# ### Selecting dimensionality reduction type example
#
# https://scikit-learn.org/stable/auto_examples/compose/plot_compare_reduction.html

# %%
best_estimator = clf.best_estimator_
best_estimator.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('select_columns', ColumnRemover(cols=['Id'])),
#                                  ('object_to_cat_or_num',
#                                   ObjectsColumnaAsType()),
#                                  ('remove_nan_columns', NanColumnsRemover()),
#                                  ('feature_union',
#                                   PandasFeatureUnion(transformer_list=[('numeric_features',
#                                                                         Pipeline(steps=[('typeselector',
#                                                                                          TypeSelector(dtype=<class 'numpy.number'>)),
#                                                                                         ('pandasimputer',
#                                                                                          P...
#                                                                                          TypeSelector(dtype='category')),
#                                                                                         ('cattoint',
#                                                                                          CatToInt()),
#                                                                                         ('pandasimputer',
#                                                                                          PandasImputer(strategy='most_frequent')),
#                                                                                         ('pandasonehotencoder',
#                                                                                          PandasOneHotEncoder())])),
#                                                                        ('boolean_features',
#                                                                         Pipeline(steps=[('typeselector',
#                                                                                          TypeSelector(dtype=<class 'bool'>)),
#                                                                                         ('pandasimputer',
#                                                                                          PandasImputer(strategy='most_frequent')),
#                                                                                         ('booltoint',
#                                                                                          BoolToInt())]))]))])),
#                 ('clf', Lasso(alpha=3))])

# %% [markdown]
# ## Saving and loading

# %%
best_estimator.predict(X_test)[:10]
# Out:
# array([155139.83813614, 265659.13343567, 123340.81938772, 233302.34950032,
#        264883.44259523,  40958.443787  , 219732.23099432, 139473.6863763 ,
#         39082.42007581, 151440.70805662])

# %%
import joblib
joblib.dump(best_estimator, FINAL_MODEL_PATH)
loaded_model = joblib.load(FINAL_MODEL_PATH)
loaded_model.predict(X_test)[:10]
# Out:
# array([155139.83813614, 265659.13343567, 123340.81938772, 233302.34950032,
#        264883.44259523,  40958.443787  , 219732.23099432, 139473.6863763 ,
#         39082.42007581, 151440.70805662])

# %% [markdown]
# # 2. Stacking

# %%
from catboost import CatBoostRegressor
from sklearn.ensemble import StackingRegressor

estimators = [
    ('catboost1', CatBoostRegressor(iterations = 1, subsample = 0.5)),
    ('catboost2', CatBoostRegressor(iterations = 1))]

stacking_clf = StackingRegressor(estimators=estimators, final_estimator=CatBoostRegressor(iterations = 1), passthrough = False)


clf = Pipeline([
    ('preprocess', preprocess),
    ('clf',stacking_clf)
])

clf.fit(X_train, y_train).score(X_test, y_test)
# Out:
# Learning rate set to 0.5
# 0:	learn: 57236.6190786	total: 56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57354.0145258	total: 2.08ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57707.5293576	total: 2.06ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54470.1848545	total: 2.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56777.5532270	total: 1.57ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56564.5964865	total: 1.53ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58429.1562621	total: 1.67ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57976.8616155	total: 1.57ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55411.3103182	total: 1.84ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55782.1724428	total: 2.74ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56449.9927225	total: 1.65ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57161.0192619	total: 1.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58014.0234415	total: 1.05ms	remaining: 0us
# 0.39323095654411455

# %%
clf_pipeline = Pipeline([
    ('preprocess', preprocess),
    ('clf', stacking_clf)
])
params = {'preprocess__remove_nan_columns__p':[0.5],} 
clf = GridSearchCV(clf_pipeline, params)
clf.fit(X_train, y_train)
pd.DataFrame(clf.cv_results_)
# Out:
# Learning rate set to 0.5
# 0:	learn: 57707.5293576	total: 2.52ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57976.8616155	total: 1.68ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54844.6645467	total: 1.6ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57110.3632825	total: 1.54ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58309.6755141	total: 1.64ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56899.6442665	total: 1.45ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 60763.9479788	total: 1.48ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57040.5110558	total: 2.28ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57713.0395835	total: 1.44ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55662.3993835	total: 1.45ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56766.4293272	total: 1.41ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58654.4423426	total: 1.44ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57911.0990377	total: 1.07ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54470.1848545	total: 2.7ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55411.3103182	total: 1.85ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54829.9669638	total: 1.73ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55254.5722136	total: 1.67ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 53457.0803802	total: 1.66ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55856.1586350	total: 1.62ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58001.4734809	total: 1.49ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58080.0089075	total: 1.46ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55994.3797520	total: 1.44ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 51789.7861569	total: 1.57ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55856.1586350	total: 1.71ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58001.4734809	total: 1.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55962.4785306	total: 2.43ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56777.5532270	total: 3.15ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55782.1724428	total: 2.41ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54949.1138839	total: 2.37ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 52344.4891342	total: 1.69ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55136.5877196	total: 2.07ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56587.3687618	total: 1.65ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58423.7947655	total: 1.57ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54266.8683162	total: 1.43ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 51865.2329170	total: 1.4ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56527.5844355	total: 1.82ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56587.3687618	total: 1.61ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55874.8004446	total: 1.71ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57257.0732809	total: 809us	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56564.5964865	total: 2.47ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56449.9927225	total: 1.79ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58346.9951671	total: 1.53ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57293.8203783	total: 1.67ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57270.2259890	total: 1.5ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56595.9741936	total: 1.54ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 61288.8197988	total: 1.49ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58903.6266459	total: 1.43ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55439.0892365	total: 1.87ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57664.6477823	total: 1.54ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57794.9097895	total: 1.5ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 59587.3638390	total: 1.44ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57571.5803791	total: 709us	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58429.1562621	total: 3.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57161.0192619	total: 2.52ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57300.7704153	total: 1.8ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58379.6647069	total: 1.54ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 59512.7196812	total: 1.85ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57029.3222420	total: 1.49ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58804.9440442	total: 1.57ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57084.6256401	total: 1.47ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56815.9783589	total: 1.41ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 59512.7196812	total: 1.4ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56023.6544833	total: 1.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58160.2384214	total: 1.54ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58412.9401056	total: 638us	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57236.6190786	total: 2.65ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57354.0145258	total: 1.73ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57707.5293576	total: 1.88ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 54470.1848545	total: 1.72ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56777.5532270	total: 1.51ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56564.5964865	total: 1.55ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58429.1562621	total: 1.98ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57976.8616155	total: 1.62ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55411.3103182	total: 1.73ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 55782.1724428	total: 1.55ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 56449.9927225	total: 1.58ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 57161.0192619	total: 2.27ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 58014.0234415	total: 1.46ms	remaining: 0us
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.277341      0.006894         0.062531        0.017356
#
#   param_preprocess__remove_nan_columns__p  \
# 0                                     0.5
#
#                                        params  split0_test_score  \
# 0  {'preprocess__remove_nan_columns__p': 0.5}           0.429358
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.468881            0.38445           0.442573           0.497639
#
#    mean_test_score  std_test_score  rank_test_score
# 0          0.44458        0.038098                1

# %%
clf.get_params().keys()
# Out:
# dict_keys(['cv', 'error_score', 'estimator__memory', 'estimator__steps', 'estimator__verbose', 'estimator__preprocess', 'estimator__clf', 'estimator__preprocess__memory', 'estimator__preprocess__steps', 'estimator__preprocess__verbose', 'estimator__preprocess__select_columns', 'estimator__preprocess__object_to_cat_or_num', 'estimator__preprocess__remove_nan_columns', 'estimator__preprocess__feature_union', 'estimator__preprocess__select_columns__cols', 'estimator__preprocess__remove_nan_columns__p', 'estimator__preprocess__feature_union__n_jobs', 'estimator__preprocess__feature_union__transformer_list', 'estimator__preprocess__feature_union__transformer_weights', 'estimator__preprocess__feature_union__verbose', 'estimator__preprocess__feature_union__numeric_features', 'estimator__preprocess__feature_union__categorical_features', 'estimator__preprocess__feature_union__boolean_features', 'estimator__preprocess__feature_union__numeric_features__memory', 'estimator__preprocess__feature_union__numeric_features__steps', 'estimator__preprocess__feature_union__numeric_features__verbose', 'estimator__preprocess__feature_union__numeric_features__typeselector', 'estimator__preprocess__feature_union__numeric_features__pandasimputer', 'estimator__preprocess__feature_union__numeric_features__pandasstandardscaler', 'estimator__preprocess__feature_union__numeric_features__typeselector__dtype', 'estimator__preprocess__feature_union__numeric_features__pandasimputer__strategy', 'estimator__preprocess__feature_union__categorical_features__memory', 'estimator__preprocess__feature_union__categorical_features__steps', 'estimator__preprocess__feature_union__categorical_features__verbose', 'estimator__preprocess__feature_union__categorical_features__typeselector', 'estimator__preprocess__feature_union__categorical_features__cattoint', 'estimator__preprocess__feature_union__categorical_features__pandasimputer', 'estimator__preprocess__feature_union__categorical_features__pandasonehotencoder', 'estimator__preprocess__feature_union__categorical_features__typeselector__dtype', 'estimator__preprocess__feature_union__categorical_features__pandasimputer__strategy', 'estimator__preprocess__feature_union__boolean_features__memory', 'estimator__preprocess__feature_union__boolean_features__steps', 'estimator__preprocess__feature_union__boolean_features__verbose', 'estimator__preprocess__feature_union__boolean_features__typeselector', 'estimator__preprocess__feature_union__boolean_features__pandasimputer', 'estimator__preprocess__feature_union__boolean_features__booltoint', 'estimator__preprocess__feature_union__boolean_features__typeselector__dtype', 'estimator__preprocess__feature_union__boolean_features__pandasimputer__strategy', 'estimator__clf__cv', 'estimator__clf__estimators', 'estimator__clf__final_estimator__iterations', 'estimator__clf__final_estimator__loss_function', 'estimator__clf__final_estimator', 'estimator__clf__n_jobs', 'estimator__clf__passthrough', 'estimator__clf__verbose', 'estimator__clf__catboost1', 'estimator__clf__catboost2', 'estimator__clf__catboost1__iterations', 'estimator__clf__catboost1__loss_function', 'estimator__clf__catboost1__subsample', 'estimator__clf__catboost2__iterations', 'estimator__clf__catboost2__loss_function', 'estimator', 'iid', 'n_jobs', 'param_grid', 'pre_dispatch', 'refit', 'return_train_score', 'scoring', 'verbose'])
